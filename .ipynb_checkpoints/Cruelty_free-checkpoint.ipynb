# %% [markdown]
# # Cruelty Free Companies #

# %% [markdown]
# <img src=https://upload.wikimedia.org/wikipedia/commons/6/6f/Cruelty-Free-TN.jpg width=200 align="left">

# %% [markdown]
# ###### This file is licensed under the Creative Commons Attribution-Share Alike 4.0 International license. ######

# %% [markdown]
# <br><br>I will be getting the initial list from [Logical Harmony](https://logicalharmony.net/cruelty-free-brand-list/).

# %%
# import libraries
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://logicalharmony.net/cruelty-free-brand-list/")
page
# Out:
# <Response [200]>

# %%
# page.content

# %%
soup = BeautifulSoup(page.content, parser="html.parser")

# %%
# print(soup.prettify())

# %%
bullets = soup.find_all('li')
# bullets

# %%
bullets[0]
# Out:
# <li><a href="https://instagram.com/logicalharmony" rel="nofollow" target="_blank"><i class="fab fa-instagram"></i></a></li>

# %%
bullets[0].get_text()
# Out:
# ''

# %%
bullets[45].get_text()
# Out:
# '100% Pure'

# %%
len(bullets)
# Out:
# 937

# %%
bullets[912].get_text()
# Out:
# 'Zyderma HS – 100% vegan!'

# %% [markdown]
# I'll need to find a way to find just the products as the website changes, but as of now I'll just use 45 - 912.

# %%
products1 = []
for p in range(45,913):
    products1.append(bullets[p].get_text())

# %%
products1[:12]
# Out:
# ['100% Pure',
#  '100BON – 100% vegan!',
#  '1121 Apothecary – 100% vegan!',
#  '21 Drops – 100% vegan!',
#  '2B',
#  '2nd KIND – 100% vegan!',
#  '7 Virtues, The – 100% vegan!',
#  '8 Greens',
#  '',
#  'A Girl’s Gotta Spa – 100% vegan!',
#  'ABBA Pure Performance Hair Care\xa0–\xa0It should be noted that they are cruelty-free, but their parent company is not.',
#  'Ace Beaute – Black-owned brand']

# %%
products1[-12:]
# Out:
# ['Youth to the People – 100% vegan! It should be noted that they are cruelty-free, but their parent company is not.',
#  'Yu-Be',
#  'Z Natural Life – 100% vegan!',
#  'Zabana Essentials – 100% vegan!',
#  'ZAK Body Care/ZAK Detox Deodorant',
#  'Zaya Eco Skincare – 100% vegan!',
#  'Zoella Beauty',
#  'Zoeva',
#  'Zoya',
#  'Zurvita',
#  'ZuZu Luxe',
#  'Zyderma HS – 100% vegan!']

# %%
# turn product list into a dataframe
import pandas as pd
prod1 = pd.DataFrame(products1)

# %%
prod1.head()
# Out:
#                                0
# 0                      100% Pure
# 1           100BON – 100% vegan!
# 2  1121 Apothecary – 100% vegan!
# 3         21 Drops – 100% vegan!
# 4                             2B

# %%
prod1 = prod1.rename(columns={0:'Company'})
prod1.head()
# Out:
#                          Company
# 0                      100% Pure
# 1           100BON – 100% vegan!
# 2  1121 Apothecary – 100% vegan!
# 3         21 Drops – 100% vegan!
# 4                             2B

# %%
# Create a new column that tells whether or not a product is vegan
prod1['Is_vegan'] = prod1['Company'].str.contains('100% vegan')

# %%
prod1.head()
# Out:
#                          Company  Is_vegan
# 0                      100% Pure     False
# 1           100BON – 100% vegan!      True
# 2  1121 Apothecary – 100% vegan!      True
# 3         21 Drops – 100% vegan!      True
# 4                             2B     False

# %%
prod1['Company'].str.contains('parent company').sum()
# Out:
# 52

# %%
prod1['Parent_co_NOT_cruelty_free'] = prod1['Company'].str.contains('parent company')

# %%
prod1.head()
# Out:
#                          Company  Is_vegan  Parent_co_NOT_cruelty_free
# 0                      100% Pure     False                       False
# 1           100BON – 100% vegan!      True                       False
# 2  1121 Apothecary – 100% vegan!      True                       False
# 3         21 Drops – 100% vegan!      True                       False
# 4                             2B     False                       False

# %%
prod1['Company'].str.contains('Black-owned').sum()
# Out:
# 52

# %%
prod1['Black_owned'] = prod1['Company'].str.contains('Black-owned')
prod1.head()
# Out:
#                          Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 0                      100% Pure     False                       False
# 1           100BON – 100% vegan!      True                       False
# 2  1121 Apothecary – 100% vegan!      True                       False
# 3         21 Drops – 100% vegan!      True                       False
# 4                             2B     False                       False
#
#    Black_owned
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
bullets[45]
# Out:
# <li><a data-id="/tag/100-pure/" data-type="URL" href="/tag/100-pure/">100% Pure</a></li>

# %%
prod1['Website'] = 'none'
prod1.head()
# Out:
#                          Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 0                      100% Pure     False                       False
# 1           100BON – 100% vegan!      True                       False
# 2  1121 Apothecary – 100% vegan!      True                       False
# 3         21 Drops – 100% vegan!      True                       False
# 4                             2B     False                       False
#
#    Black_owned Website
# 0        False    none
# 1        False    none
# 2        False    none
# 3        False    none
# 4        False    none

# %%
prod1.iloc[0,4]
# Out:
# 'none'

# %%
prod1.drop('Website', inplace=True, axis=1)
prod1.head()
# Out:
#                          Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 0                      100% Pure     False                       False
# 1           100BON – 100% vegan!      True                       False
# 2  1121 Apothecary – 100% vegan!      True                       False
# 3         21 Drops – 100% vegan!      True                       False
# 4                             2B     False                       False
#
#    Black_owned
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
prod_col = prod1['Company']
prod_col = pd.DataFrame(prod_col)
prod_col.head()
# Out:
#                          Company
# 0                      100% Pure
# 1           100BON – 100% vegan!
# 2  1121 Apothecary – 100% vegan!
# 3         21 Drops – 100% vegan!
# 4                             2B

# %%
with_hyphens = prod_col[prod_col['Company'].str.contains(' – 100% vegan!')]
with_hyphens
# Out:
#                                                Company
# 1                                 100BON – 100% vegan!
# 2                        1121 Apothecary – 100% vegan!
# 3                               21 Drops – 100% vegan!
# 5                               2nd KIND – 100% vegan!
# 6                         7 Virtues, The – 100% vegan!
# ..                                                 ...
# 856  Youth to the People – 100% vegan! It should be...
# 858                       Z Natural Life – 100% vegan!
# 859                    Zabana Essentials – 100% vegan!
# 861                    Zaya Eco Skincare – 100% vegan!
# 867                           Zyderma HS – 100% vegan!
#
# [339 rows x 1 columns]

# %%
# start to simplify the company name by removing attributes already noted in new columns
prods = prod1.copy() 
prods['Company'] = prod1['Company'].str.replace(' – 100% vegan!', '')
prods.head()
# Out:
#            Company  Is_vegan  Parent_co_NOT_cruelty_free  Black_owned
# 0        100% Pure     False                       False        False
# 1           100BON      True                       False        False
# 2  1121 Apothecary      True                       False        False
# 3         21 Drops      True                       False        False
# 4               2B     False                       False        False

# %%
still_hyphens = prods[prods['Company'].str.contains('–')]
still_hyphens
# Out:
#                                                Company  Is_vegan  \
# 10   ABBA Pure Performance Hair Care – It should be...     False
# 11                      Ace Beaute – Black-owned brand     False
# 19                     Aeva Beauty – Black-owned brand     False
# 20                     Afrocenchix – Black-owned brand      True
# 40                     Anita Grant – Black-owned brand     False
# ..                                                 ...       ...
# 801  TRESemmé – It should be noted that they are cr...     False
# 814                Unsun Cosmetics – Black-owned brand     False
# 816                    Uoma Beauty – Black-owned brand     False
# 818  Urban Decay – It should be noted that they are...     False
# 827                             VIRGINIC – 100% vegan!      True
#
#      Parent_co_NOT_cruelty_free  Black_owned
# 10                         True        False
# 11                        False         True
# 19                        False         True
# ...

# %%
prods['Company'] = prods['Company'].str.replace(' – Black-owned brand', '')
prods.head(30)
# Out:
#                                               Company  Is_vegan  \
# 0                                           100% Pure     False
# 1                                              100BON      True
# 2                                     1121 Apothecary      True
# 3                                            21 Drops      True
# 4                                                  2B     False
# 5                                            2nd KIND      True
# 6                                      7 Virtues, The      True
# 7                                            8 Greens     False
# 8                                                         False
# 9                                  A Girl’s Gotta Spa      True
# 10  ABBA Pure Performance Hair Care – It should be...     False
# 11                                         Ace Beaute     False
# 12                                    Acid-2-Alkaline      True
# 13                                  Activist Skincare      True
# ...

# %%
still_hyphens = prods[prods['Company'].str.contains('–')]
still_hyphens
# Out:
#                                                Company  Is_vegan  \
# 10   ABBA Pure Performance Hair Care – It should be...     False
# 20                     Afrocenchix – Black-owned brand      True
# 40                     Anita Grant – Black-owned brand     False
# 68   Aveda – It should be noted that they are cruel...     False
# 69   Awake Beauty – It should be noted that they ar...     False
# ..                                                 ...       ...
# 801  TRESemmé – It should be noted that they are cr...     False
# 814                Unsun Cosmetics – Black-owned brand     False
# 816                    Uoma Beauty – Black-owned brand     False
# 818  Urban Decay – It should be noted that they are...     False
# 827                             VIRGINIC – 100% vegan!      True
#
#      Parent_co_NOT_cruelty_free  Black_owned
# 10                         True        False
# 20                        False         True
# 40                        False         True
# ...

# %%
prods.iloc[818,0]
# Out:
# 'Urban Decay –\xa0It should be noted that they are cruelty-free, but their parent company is not.'

# %%
prods['Company'].str.contains(' –\xa0It should be noted that they are cruelty-free, but their parent company is not.').sum()
# Out:
# 20

# %%
prods[prods['Company'].str.contains(' –\xa0It should be noted that they are cruelty-free, but their parent company is not.')]
# Out:
#                                                Company  Is_vegan  \
# 83   bareMinerals – It should be noted that they ar...     False
# 147  Buxom – It should be noted that they are cruel...     False
# 163  Chemistry Brand, The – It should be noted that...     False
# 206  dermaGEEK – It should be noted that they are c...      True
# 207  Dermalogica – It should be noted that they are...     False
# 237  Ecover – It should be noted that they are crue...      True
# 275  Flesh Beauty – It should be noted that they ar...     False
# 294  Garnier – It should be noted that they are cru...     False
# 344  Hourglass (Hourglass Cosmetics vegan product l...     False
# 349  Hylamide – It should be noted that they are cr...     False
# 426  Kylie Skin – It should be noted that they are ...      True
# 518  Method – It should be noted that they are crue...      True
# 565  NIOD – It should be noted that they are cruelt...     False
# ...

# %%
prods['Company'] = prods['Company'].str.replace(' –\xa0It should be noted that they are cruelty-free, but their parent company is not.', '')
prods.head()
# Out:
# /var/folders/pw/9j0pzyrs615dkcjzj755q6nr0000gn/T/ipykernel_24919/1895888690.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   prods['Company'] = prods['Company'].str.replace(' –\xa0It should be noted that they are cruelty-free, but their parent company is not.', '')
#            Company  Is_vegan  Parent_co_NOT_cruelty_free  Black_owned
# 0        100% Pure     False                       False        False
# 1           100BON      True                       False        False
# 2  1121 Apothecary      True                       False        False
# 3         21 Drops      True                       False        False
# 4               2B     False                       False        False

# %%
still_hyphens = prods[prods['Company'].str.contains('–')]
still_hyphens
# Out:
#                                                Company  Is_vegan  \
# 10   ABBA Pure Performance Hair Care – It should be...     False
# 20                     Afrocenchix – Black-owned brand      True
# 40                     Anita Grant – Black-owned brand     False
# 68   Aveda – It should be noted that they are cruel...     False
# 69   Awake Beauty – It should be noted that they ar...     False
# ..                                                 ...       ...
# 795  Too Faced – It should be noted that they are c...     False
# 801  TRESemmé – It should be noted that they are cr...     False
# 814                Unsun Cosmetics – Black-owned brand     False
# 816                    Uoma Beauty – Black-owned brand     False
# 827                             VIRGINIC – 100% vegan!      True
#
#      Parent_co_NOT_cruelty_free  Black_owned
# 10                         True        False
# 20                        False         True
# 40                        False         True
# ...

# %%
first_part = still_hyphens['Company'].str.split('–',-1)
first_part = pd.DataFrame(first_part)
first_part
# Out:
#                                                Company
# 10   [ABBA Pure Performance Hair Care ,  It should ...
# 20                  [Afrocenchix ,  Black-owned brand]
# 40                  [Anita Grant ,  Black-owned brand]
# 68   [Aveda ,  It should be noted that they are cru...
# 69   [Awake Beauty ,  It should be noted that they ...
# ..                                                 ...
# 795  [Too Faced ,  It should be noted that they are...
# 801  [TRESemmé ,  It should be noted that they are ...
# 814             [Unsun Cosmetics ,  Black-owned brand]
# 816                 [Uoma Beauty ,  Black-owned brand]
# 827                          [VIRGINIC ,  100% vegan!]
#
# [77 rows x 1 columns]

# %%
first_part.iloc[0][0][0]
# Out:
# 'ABBA Pure Performance Hair Care\xa0'

# %%
first_part['try_this'] = prods['Company'].str.split('–').str[0]
first_part.iloc[70:]
# Out:
#                                                Company          try_this
# 780  [Tarte ,  It should be noted that they are cru...            Tarte
# 784                           [Teadora ,  100% vegan!]          Teadora
# 795  [Too Faced ,  It should be noted that they are...        Too Faced
# 801  [TRESemmé ,  It should be noted that they are ...         TRESemmé
# 814             [Unsun Cosmetics ,  Black-owned brand]  Unsun Cosmetics
# 816                 [Uoma Beauty ,  Black-owned brand]      Uoma Beauty
# 827                          [VIRGINIC ,  100% vegan!]         VIRGINIC

# %%
prods['Company'] = prods['Company'].str.split('–').str[0]
prods.head(29)
# Out:
#                              Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 0                          100% Pure     False                       False
# 1                             100BON      True                       False
# 2                    1121 Apothecary      True                       False
# 3                           21 Drops      True                       False
# 4                                 2B     False                       False
# 5                           2nd KIND      True                       False
# 6                     7 Virtues, The      True                       False
# 7                           8 Greens     False                       False
# 8                                        False                       False
# 9                 A Girl’s Gotta Spa      True                       False
# 10  ABBA Pure Performance Hair Care      False                        True
# ...

# %%
prods.drop(labels=8, inplace=True)
prods.head(10)
# Out:
#                              Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 0                          100% Pure     False                       False
# 1                             100BON      True                       False
# 2                    1121 Apothecary      True                       False
# 3                           21 Drops      True                       False
# 4                                 2B     False                       False
# 5                           2nd KIND      True                       False
# 6                     7 Virtues, The      True                       False
# 7                           8 Greens     False                       False
# 9                 A Girl’s Gotta Spa      True                       False
# 10  ABBA Pure Performance Hair Care      False                        True
#
#     Black_owned
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# ...

# %%
prods['Company'] = prods['Company'].str.replace(' It should be noted that they are cruelty-free, but their parent company is not.','')
prods.tail(30)
# Out:
# /var/folders/pw/9j0pzyrs615dkcjzj755q6nr0000gn/T/ipykernel_24919/3905218424.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   prods['Company'] = prods['Company'].str.replace(' It should be noted that they are cruelty-free, but their parent company is not.','')
#                                Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 838                       We Love Eyes      True                       False
# 839                             Weleda     False                       False
# 840                         Well Scent      True                       False
# 841                 Well Organics, The     False                       False
# 842               Wellness Prioritized      True                       False
# 843                   Wen by Chaz Dean     False                       False
# 844              Whole Foods Brand/365     False                       False
# ...

# %% [markdown]
# ### How many have parent companies that are not cruelty free ###

# %%
# import graphing packages
import matplotlib.pyplot as plt
import seaborn as sns

fig = sns.countplot(data=prods, x='Parent_co_NOT_cruelty_free')
fig.set_ylabel('Number of cruelty free companies');

# %%
# now try with plotly
import plotly.express as px

px.histogram(prods, x='Parent_co_NOT_cruelty_free');
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/pw/9j0pzyrs615dkcjzj755q6nr0000gn/T/ipykernel_24919/1319893506.py in <module>
#       1 # now try with plotly
# ----> 2 import plotly.express as px
#       3
#       4 px.histogram(prods, x='Parent_co_NOT_cruelty_free');
#
# ModuleNotFoundError: No module named 'plotly'

# %%
fig = sns.countplot(data=prods, x='Black_owned')
fig.set_ylabel('Black-owned companies');

# %%
fig = sns.countplot(data=prods, x='Is_vegan')
fig.set_ylabel('Number of vegan companies');

# %%
veg_cf_black = prods[prods.Is_vegan & prods.Black_owned & ~prods.Parent_co_NOT_cruelty_free]

# %% [markdown]
# ## Companies that are vegan, black-owned, *and* do not have a parent company that isn't cruelty free ##

# %%
veg_cf_black
# Out:
#                            Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 20                    Afrocenchix       True                       False
# 200                        Dehiya       True                       False
# 213                Dimension Nails      True                       False
# 214            Dirt Don’t Hurt Me       True                       False
# 370          Jane Carter Solution       True                       False
# 478   LYS Beauty Black-owned brand      True                       False
# 513              Mented Cosmetics       True                       False
# 527                     Mocha Whip      True                       False
# 551                   Nash + Pino       True                       False
# 595  OOO Polish (Triple O Polish)       True                       False
# 623                      Pear Nova      True                       False
# 627        People of Color Beauty       True                       False
# ...

# %% [markdown]
# ## Black-owned companies ##

# %%
black = prods[prods.Black_owned]
black
# Out:
#                               Company  Is_vegan  Parent_co_NOT_cruelty_free  \
# 11                         Ace Beaute     False                       False
# 19                        Aeva Beauty     False                       False
# 20                       Afrocenchix       True                       False
# 40                       Anita Grant      False                       False
# 95              BeautyStat Cosmetics      False                       False
# 96                    Beauty Bakerie      False                       False
# 99                    Beauty By Stony     False                       False
# 129                   Bold Brand, The     False                       False
# 134  Bossy Cosmetics (Bossy Lipstick)     False                       False
# 139                          Briogeo      False                       False
# 176         Coloured Raine Cosmetics      False                       False
# ...

# %% [markdown]
# ## "Cruelty free" products whose parent companies are *NOT* cruelty free! ##

# %%
sneaky = prods[prods.Parent_co_NOT_cruelty_free]
sneaky
# Out:
#                                                Company  Is_vegan  \
# 10                    ABBA Pure Performance Hair Care      False
# 68                                              Aveda      False
# 69                                       Awake Beauty      False
# 83                                        bareMinerals     False
# 102                                             Becca      False
# 145                                       Burt’s Bees      False
# 147                                              Buxom     False
# 154                                           Caldrea      False
# 159  Certain Dri It should be noted that they are c...      True
# 163                               Chemistry Brand, The     False
# 186                                         COVERGIRL      False
# 205                           Dermablend Professional      False
# 206                                          dermaGEEK      True
# ...

# %% [markdown]
# Next, I'll be looking for brands sold by different stores.
